# %%
# !pip install -q psycopg2-binary
# Out:
# [notice] A new release of pip is available: 26.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
facebook = pd.read_csv("01_facebook_ads.csv")
google = pd.read_csv("02_google_ads.csv")
tiktok = pd.read_csv("03_tiktok_ads.csv")

# %%
print(',\n'.join(facebook.columns))
# Out:
# date,
# campaign_id,
# campaign_name,
# ad_set_id,
# ad_set_name,
# impressions,
# clicks,
# spend,
# conversions,
# video_views,
# engagement_rate,
# reach,
# frequency

# %%
print(',\n'.join(google.columns))
# Out:
# date,
# campaign_id,
# campaign_name,
# ad_group_id,
# ad_group_name,
# impressions,
# clicks,
# cost,
# conversions,
# conversion_value,
# ctr,
# avg_cpc,
# quality_score,
# search_impression_share

# %%
from getpass import getpass
from urllib.parse import quote_plus
password = quote_plus(getpass("DB password: "))
DB_URL = f"postgresql://postgres:{password}@db.oninlvungqpvughmfeum.supabase.co:5432/postgres"
engine = create_engine(DB_URL)
# Out:
# DB password:  ········

# %%
files = {
    "table_a": "01_facebook_ads.csv",
    "table_b": "02_google_ads.csv",
    "table_c": "03_tiktok_ads.csv",
}
